# %% [markdown]
# # 🎙️ AI Voice Cloning Tool
# ## English · Hindi · Bangla
# Run this notebook on T4 GPU for free unlimited voice cloning.

# %%
# %cd /content/
# !git clone https://github.com/resemble-ai/chatterbox.git

# Download app.py and __init__.py from your GitHub raw URL
# !wget -O /content/app.py https://raw.githubusercontent.com/YOUR_USERNAME/YOUR_REPO/main/backend/app.py
# !wget -O /content/chatterbox/src/chatterbox/__init__.py https://raw.githubusercontent.com/YOUR_USERNAME/YOUR_REPO/main/backend/__init__.py

# !pip install numpy~=1.26.0 resampy==0.4.3 librosa==0.11.0 s3tokenizer==0.2.0 torchcodec==0.8.1 transformers==4.46.3 diffusers==0.29.0 resemble-perth==1.0.1 omegaconf==2.3.0 conformer==0.3.2 safetensors==0.5.3 sentencex==0.6.1 pydub==0.25.1 soundfile==0.13.1 gradio>=4.0.0 tqdm

import sys, os
sys.path.insert(0, '/content/chatterbox/src')
print("✅ All installed. Kernel will NOT restart now.")

# %%
# %cd /content/
# !python app.py --share
